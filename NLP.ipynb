# %%
from pathlib import Path

# %%
from textblob import TextBlob

# %%
import pandas as pd

# %%
blob = TextBlob(Path("Lady Lucy's secret;.txt").read_text())

# %%
blob
# Out:
# TextBlob("﻿The Project Gutenberg eBook of Lady Lucy's secret;
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.
#
# Title: Lady Lucy's secret;
#         or, the gold thimble
#
# Author: Lucy Ellen Guernsey
#
# Release date: December 11, 2024 [eBook #74876]
#
# Language: English
#
# Original publication: United States: American Sunday-School Union
#
#
# *** START OF THE PROJECT GUTENBERG EBOOK LADY LUCY'S SECRET; ***
#
# Transcriber's notes: Unusual and inconsistent spelling is as printed.
#  New original cover art included with this eBook is granted to the
# public domain.
#
#
#
# ...

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stop_words = stopwords.words("english")

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
items = blob.word_counts.items()

# %%
items = [item for item in items if item[0] not in stop_words]

# %%
from operator import itemgetter

# %%
sorted_items = sorted(items, key=itemgetter(1), reverse=True)

# %%
top30 = sorted_items[:30]

# %%
top30
# Out:
# [('lucy', 373),
#  ('cousin', 191),
#  ('said', 170),
#  ('anne', 128),
#  ('would', 108),
#  ('little', 106),
#  ('lady', 103),
#  ('deborah', 90),
#  ('project', 88),
#  ('see', 82),
#  ('bernard', 81),
#  ('one', 80),
#  ('never', 74),
#  ('aunt', 73),
#  ('work', 72),
#  ('shall', 72),
#  ('debby', 69),
#  ('upon', 66),
#  ('old', 65),
#  ('good', 63),
#  ('tell', 61),
#  ('may', 60),
#  ('thimble', 60),
#  ('child', 59),
#  ('know', 59),
#  ('gutenberg™', 57),
#  ('father', 55),
#  ('must', 55),
#  ('dear', 55),
#  ("n't", 54)]

# %%
df = pd.DataFrame(top30, columns=["word", "count"])

# %%
df
# Out:
#           word  count
# 0         lucy    373
# 1       cousin    191
# 2         said    170
# 3         anne    128
# 4        would    108
# 5       little    106
# 6         lady    103
# 7      deborah     90
# 8      project     88
# 9          see     82
# 10     bernard     81
# 11         one     80
# 12       never     74
# 13        aunt     73
# 14        work     72
# 15       shall     72
# 16       debby     69
# 17        upon     66
# 18         old     65
# 19        good     63
# 20        tell     61
# 21         may     60
# 22     thimble     60
# 23       child     59
# 24        know     59
# 25  gutenberg™     57
# 26      father     55
# 27        must     55
# 28        dear     55
# 29         n't     54

# %%
axes = df.plot.bar(x="word", y="count", legend=False)

# %%
pip install wordcloud

# %%
import imageio

# %%
mask_image = imageio.imread("mask_circle.png")
# Out:
# <ipython-input-30-0dba3b5e8d4d>:1: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   mask_image = imageio.imread("mask_circle.png")

# %%
from wordcloud import WordCloud

# %%
workcloud = WordCloud(colormap="prism", mask=mask_image, background_color="white")

# %%
text = Path("Lady Lucy's secret;.txt").read_text()

# %%
workcloud = workcloud.generate(text)

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(workcloud)

# %% [markdown]
# exercises

# %%
pip install textatistic
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for textatistic: filename=textatistic-0.0.1-py3-none-any.whl size=29047 sha256=22248ee9cea825eb0e7964da92757c5a4193d9b65bc09493279d1077f24125fa
#   Stored in directory: /root/.cache/pip/wheels/6e/31/c3/df8af4aa9ec3f671b0e8bc3bfa642c75918f2479ca4050f5f4
# ...
#   Created wheel for pyhyphen: filename=PyHyphen-4.0.4-cp37-abi3-linux_x86_64.whl size=65468 sha256=cb1bb960bd840517757f344eb3b421f6fcf98e8b68601b1d4e1ab3ba38b26322
#   Stored in directory: /root/.cache/pip/wheels/a0/39/c3/1b8e8428660809de72abc6f40f078bb04d7eb36f7d945e5933
# Successfully built textatistic pyhyphen
# ...

# %%
from textatistic import Textatistic

# %%
readability = Textatistic(text)

# %% [markdown]
# readability.dict()

# %%
text
# Out:
# '\ufeffThe Project Gutenberg eBook of Lady Lucy\'s secret;\n    \nThis ebook is for the use of anyone anywhere in the United States and\nmost other parts of the world at no cost and with almost no restrictions\nwhatsoever. You may copy it, give it away or re-use it under the terms\nof the Project Gutenberg License included with this ebook or online\nat www.gutenberg.org. If you are not located in the United States,\nyou will have to check the laws of the country where you are located\nbefore using this eBook.\n\nTitle: Lady Lucy\'s secret;\n        or, the gold thimble\n\nAuthor: Lucy Ellen Guernsey\n\nRelease date: December 11, 2024 [eBook #74876]\n\nLanguage: English\n\nOriginal publication: United States: American Sunday-School Union\n\n\n*** START OF THE PROJECT GUTENBERG EBOOK LADY LUCY\'S SECRET; ***\n\nTranscriber\'s notes: Unusual and inconsistent spelling is as printed.\n New original cover art included with this eBook is granted to the\npublic domain.\n\n\n\n               
# ...

# %%
from textblob import Word

# %%
wordd = Word(top30[23][0])

# %%
wordd.pluralize()
# Out:
# 'children'

# %%
word = Word(top30[22][0])

# %%
word.stem()
# Out:
# 'thimbl'
